# %%
from uuid import uuid4
import os

import numpy as np
import torch
import torch.nn.functional as F
from PIL import Image
from torchvision import transforms

from unet import UNet
from utils.dataset import BasicDataset
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# https://gitlab.nanosemantics.ru/na/cv/rl-mri/blob/norm/utils/dataset.py

# %%
from PIL import ImageOps 
image=Image.open('data/imgs/01064.PNG')
# print(image.size)
equalized=ImageOps.equalize(image)
# Out:
# (320, 316)

# %%
plt.imshow(image)

# %%
plt.imshow(equalized)

# %%
img = cv2.imread('data/imgs/01064.PNG')
normalized_image = cv2.normalize(img,None, alpha=0, beta=0.3, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)

# %%
plt.imshow(img)

# %%
plt.imshow(normalized_image)

# %%
img = cv2.imread('data/imgs/01064.PNG')
normalized_image = cv2.normalize(img,None, alpha=0, beta=1, norm_type=cv2.NORM_L1, dtype=cv2.CV_32F)

# %%
plt.imshow(img)

# %%
plt.imshow(normalized_image)
